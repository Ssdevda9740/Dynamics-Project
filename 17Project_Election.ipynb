# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
el=pd.read_csv('Election_data.csv', parse_dates=['time'])
el
# Out:
#        TimeElapsed                time        territoryName  totalMandates  \
# 0                0 2019-06-10 20:10:00  Território Nacional              0
# 1                0 2019-06-10 20:10:00  Território Nacional              0
# 2                0 2019-06-10 20:10:00  Território Nacional              0
# 3                0 2019-06-10 20:10:00  Território Nacional              0
# 4                0 2019-06-10 20:10:00  Território Nacional              0
# ...            ...                 ...                  ...            ...
# 21638          265 2019-07-10 00:35:00                Viseu              8
# 21639          265 2019-07-10 00:35:00                Viseu              8
# 21640          265 2019-07-10 00:35:00                Viseu              8
# 21641          265 2019-07-10 00:35:00                Viseu              8
# 21642          265 2019-07-10 00:35:00                Viseu              8
#
# ...

# %%
el.dtypes
# Out:
# TimeElapsed                          int64
# time                        datetime64[ns]
# territoryName                       object
# totalMandates                        int64
# availableMandates                    int64
# numParishes                          int64
# numParishesApproved                  int64
# blankVotes                           int64
# blankVotesPercentage               float64
# nullVotes                            int64
# nullVotesPercentage                float64
# votersPercentage                   float64
# subscribedVoters                     int64
# totalVoters                          int64
# pre.blankVotes                       int64
# pre.blankVotesPercentage           float64
# pre.nullVotes                        int64
# pre.nullVotesPercentage            float64
# pre.votersPercentage               float64
# pre.subscribedVoters                 int64
# pre.totalVoters                      int64
# Party                               object
# ...

# %%
el.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
el['territoryName']=le.fit_transform(el['territoryName'])
el['Party']=le.fit_transform(el['Party'])

# %%
el.dtypes
# Out:
# TimeElapsed                          int64
# time                        datetime64[ns]
# territoryName                        int32
# totalMandates                        int64
# availableMandates                    int64
# numParishes                          int64
# numParishesApproved                  int64
# blankVotes                           int64
# blankVotesPercentage               float64
# nullVotes                            int64
# nullVotesPercentage                float64
# votersPercentage                   float64
# subscribedVoters                     int64
# totalVoters                          int64
# pre.blankVotes                       int64
# pre.blankVotesPercentage           float64
# pre.nullVotes                        int64
# pre.nullVotesPercentage            float64
# pre.votersPercentage               float64
# pre.subscribedVoters                 int64
# pre.totalVoters                      int64
# Party                                int32
# ...

# %%
el
# Out:
#        TimeElapsed                time  territoryName  totalMandates  \
# 0                0 2019-06-10 20:10:00             16              0
# 1                0 2019-06-10 20:10:00             16              0
# 2                0 2019-06-10 20:10:00             16              0
# 3                0 2019-06-10 20:10:00             16              0
# 4                0 2019-06-10 20:10:00             16              0
# ...            ...                 ...            ...            ...
# 21638          265 2019-07-10 00:35:00             19              8
# 21639          265 2019-07-10 00:35:00             19              8
# 21640          265 2019-07-10 00:35:00             19              8
# 21641          265 2019-07-10 00:35:00             19              8
# 21642          265 2019-07-10 00:35:00             19              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# ...

# %%
sns.heatmap(el.isnull())

# %%
el.describe()
# Out:
#         TimeElapsed  territoryName  totalMandates  availableMandates  \
# count  21643.000000   21643.000000   21643.000000       21643.000000
# mean     133.146052      10.116851      11.544795          11.499284
# std       77.651193       5.985225      31.314567          31.738783
# min        0.000000       0.000000       0.000000           0.000000
# 25%       65.000000       5.000000       1.000000           0.000000
# 50%      135.000000      10.000000       4.000000           3.000000
# 75%      200.000000      15.000000       9.000000           9.000000
# max      265.000000      20.000000     226.000000         226.000000
#
#         numParishes  numParishesApproved     blankVotes  blankVotesPercentage  \
# count  21643.000000         21643.000000   21643.000000          21643.000000
# mean     309.956013           261.090237    8875.066673              2.621629
# std      659.055911           583.377428   21484.874088              0.795289
# ...

# %%
el.corr()
# Out:
#                           TimeElapsed  territoryName  totalMandates  \
# TimeElapsed                  1.000000      -0.012674       0.260377
# territoryName               -0.012674       1.000000       0.172374
# totalMandates                0.260377       0.172374       1.000000
# availableMandates           -0.261627       0.181563       0.217404
# numParishes                 -0.001944       0.223300       0.765877
# numParishesApproved          0.100432       0.215599       0.873415
# blankVotes                   0.192350       0.178082       0.969988
# blankVotesPercentage         0.034343      -0.302412      -0.003149
# nullVotes                    0.185784       0.196554       0.967294
# nullVotesPercentage         -0.225021      -0.126432      -0.165132
# votersPercentage             0.029698       0.104222       0.171317
# subscribedVoters             0.195487       0.195483       0.974407
# totalVoters                  0.198243       0.193847       0.976336
# ...

# %%
plt.figure(figsize=(16,12))
sns.heatmap(el.corr(), annot=True, cmap='Blues')

# %%
el.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
sns.countplot(el['blankVotes'])

# %%
sns.countplot(el['pre.votersPercentage'])

# %%
sns.countplot(el['nullVotesPercentage'])

# %%
sns.distplot(el['pre.subscribedVoters'])

# %%
sns.distplot(el['totalVoters'])

# %%
sns.scatterplot(x='Mandates', y='Percentage', data=el)

# %%
sns.scatterplot(x='validVotesPercentage', y='Votes', data=el)

# %%
sns.boxplot(el['numParishes'])

# %%
sns.boxplot(el['Votes'])

# %%
sns.boxplot(el['blankVotes'])

# %%
ei=el.drop(['time'], axis=1)

# %%
from scipy.stats import zscore
z=np.abs(zscore(ei))
et=ei[(z<3).all(axis=1)]
et
# Out:
#        TimeElapsed  territoryName  totalMandates  availableMandates  \
# 22               0              0              0                 16
# 23               0              0              0                 16
# 24               0              0              0                 16
# 25               0              0              0                 16
# 26               0              0              0                 16
# ...            ...            ...            ...                ...
# 21638          265             19              8                  0
# 21639          265             19              8                  0
# 21640          265             19              8                  0
# 21641          265             19              8                  0
# 21642          265             19              8                  0
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 22             147                   12         186                  2.92
# ...

# %%
et.skew()
# Out:
# TimeElapsed                -0.024110
# territoryName               0.034073
# totalMandates               2.542453
# availableMandates           2.593527
# numParishes                 0.585363
# numParishesApproved         0.619329
# blankVotes                  1.800122
# blankVotesPercentage       -0.844508
# nullVotes                   2.103352
# nullVotesPercentage         0.564426
# votersPercentage           -0.392023
# subscribedVoters            2.407541
# totalVoters                 2.468630
# pre.blankVotes              2.034860
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes               2.340000
# pre.nullVotesPercentage     1.033803
# pre.votersPercentage       -0.514215
# pre.subscribedVoters        2.370988
# pre.totalVoters             2.468950
# Party                       0.009657
# Mandates                    7.177093
# Percentage                  3.373567
# validVotesPercentage        3.383145
# Votes                       7.310058
# ...

# %%
ec=et.copy()

# %%
ec['totalMandates']=np.log1p(ec['totalMandates'])
ec['availableMandates']=np.log1p(ec['availableMandates'])
ec['blankVotes']=np.log1p(ec['blankVotes'])
ec['nullVotes']=np.log1p(ec['nullVotes'])
ec['subscribedVoters']=np.log1p(ec['subscribedVoters'])
ec['totalVoters']=np.log1p(ec['totalVoters'])
ec['pre.nullVotes']=np.log1p(ec['pre.nullVotes'])
ec['pre.nullVotesPercentage']=np.log1p(ec['pre.nullVotesPercentage'])
ec['pre.subscribedVoters']=np.log1p(ec['pre.subscribedVoters'])
ec['Mandates']=np.log1p(ec['Mandates'])
ec['Percentage']=np.log1p(ec['Percentage'])
ec['validVotesPercentage']=np.log1p(ec['validVotesPercentage'])
ec['Votes']=np.log1p(ec['Votes'])
ec['Hondt']=np.log1p(ec['Hondt'])
ec['FinalMandates']=np.log1p(ec['FinalMandates'])

# %%
ec.skew()
# Out:
# TimeElapsed                -0.024110
# territoryName               0.034073
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                 0.585363
# numParishesApproved         0.619329
# blankVotes                 -0.592756
# blankVotesPercentage       -0.844508
# nullVotes                  -0.880145
# nullVotesPercentage         0.564426
# votersPercentage           -0.392023
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes              2.034860
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.628444
# pre.votersPercentage       -0.514215
# pre.subscribedVoters       -0.802802
# pre.totalVoters             2.468950
# Party                       0.009657
# Mandates                    4.479200
# Percentage                  1.565493
# validVotesPercentage        1.550088
# Votes                       0.268973
# ...

# %%
plt.hist(et['Votes'])
# Out:
# (array([1.7386e+04, 5.7100e+02, 1.8300e+02, 6.5000e+01, 5.1000e+01,
#         3.4000e+01, 8.0000e+00, 1.1000e+01, 1.3000e+01, 1.1000e+01]),
#  array([4.000000e+00, 2.834390e+04, 5.668380e+04, 8.502370e+04,
#         1.133636e+05, 1.417035e+05, 1.700434e+05, 1.983833e+05,
#         2.267232e+05, 2.550631e+05, 2.834030e+05]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ec['Votes'])
# Out:
# (array([ 368.,  668., 1912., 3972., 4482., 2945., 2010., 1110.,  700.,
#          166.]),
#  array([ 1.60943791,  2.70395699,  3.79847607,  4.89299515,  5.98751424,
#          7.08203332,  8.1765524 ,  9.27107148, 10.36559056, 11.46010964,
#         12.55462872]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ei['blankVotes'])
# Out:
# (array([18855.,  1822.,    21.,    84.,    84.,    42.,    84.,    84.,
#           105.,   462.]),
#  array([1.90000e+01, 1.29770e+04, 2.59350e+04, 3.88930e+04, 5.18510e+04,
#         6.48090e+04, 7.77670e+04, 9.07250e+04, 1.03683e+05, 1.16641e+05,
#         1.29599e+05]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ec['blankVotes'])
# Out:
# (array([ 171.,  598.,  640.,  517., 2035., 3226., 2630., 4051., 2742.,
#         1723.]),
#  array([ 3.71357207,  4.34955055,  4.98552903,  5.62150752,  6.257486  ,
#          6.89346448,  7.52944297,  8.16542145,  8.80139993,  9.43737842,
#         10.0733569 ]),
#  <a list of 10 Patch objects>)

# %%
x=ec.iloc[:,0:-1]
y=ec.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
x=sd.fit_transform(x)
x
# Out:
# array([[-1.75204539, -1.7413557 , -1.45485328, ...,  3.05917647,
#          0.51921323,  4.50639815],
#        [-1.75204539, -1.7413557 , -1.45485328, ...,  1.47180152,
#         -0.26051377,  1.28801031],
#        [-1.75204539, -1.7413557 , -1.45485328, ...,  1.28177   ,
#         -0.36097489,  1.28801031],
#        ...,
#        [ 1.6913844 ,  1.50873516,  0.71279768, ..., -0.78564809,
#         -0.57708825, -0.32118361],
#        [ 1.6913844 ,  1.50873516,  0.71279768, ..., -0.79532572,
#         -0.61212066, -0.32118361],
#        [ 1.6913844 ,  1.50873516,  0.71279768, ..., -0.8655444 ,
#         -0.97122055, -0.32118361]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
max_scr=0
for rstate in range(1,46):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=rstate, test_size=0.20)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_y=lr.predict(x_test)
    r2_scr=r2_score(y_test,pred_y)
    if r2_scr>max_scr:
        max_scr=r2_scr
        final_rstate=rstate
        
print('The corresponding value for the rstate', rstate,'to max r2 scr is',max_scr)
# Out:
# The corresponding value for the rstate 45 to max r2 scr is 0.9844720883498692

# %%
from sklearn.model_selection import cross_val_score
crs_val_scr=cross_val_score(lr,x,y,scoring='r2', cv=10).mean()
crs_val_scr
# Out:
# 0.9789370270042482

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso, Ridge
alpha_value={'alpha':[1,0.1,0.01,0.001]}
model=Ridge(),Lasso()
for m in model:
    grid=GridSearchCV(estimator=m, param_grid=alpha_value, cv=5)
    grid.fit(x,y)
    print(grid.best_params_)
    print(grid.best_score_)
# Out:
# {'alpha': 1}
# 0.9772327884418939
# {'alpha': 0.001}
# 0.9778948815648445

# %%
ls=Lasso(alpha=0.001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_y=ls.predict(x_test)
r2_scr=r2_score(y_test,pred_y)
print('r2 score',r2_scr)
print('mean sqaured error', mean_squared_error(y_test,pred_y))
# Out:
# r2 score 0.9747220358695504
# mean sqaured error 0.004733472459439725

# %%
rd=Ridge(alpha=1)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_y=rd.predict(x_test)
r2_scr=r2_score(y_test,pred_y)
print('r2 score',r2_scr)
print('mean sqaured error', mean_squared_error(y_test,pred_y))
# Out:
# r2 score 0.9754604618874514
# mean sqaured error 0.004595197114121966

# %%
df1=pd.DataFrame(pred_y)
df1.to_csv('lr_prediction.csv')

# %%
import joblib
joblib.dump(lr,'lr_Election.pkl')
# Out:
# ['lr_Election.pkl']
